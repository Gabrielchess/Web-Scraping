# %%
import pyautogui
from datetime import datetime, timedelta
import time
import calendar

incoterm = 'CIF'

pyautogui.alert("Tire a mão do teclado e mouse!")
pyautogui.PAUSE = 0.5

#Loguin
pyautogui.press('winleft')
pyautogui.write('chrome')
pyautogui.press('enter')

time.sleep(1)
pyautogui.write('http://hindalco.simfrete.com.br/')
pyautogui.press('enter')
  
#Entrar sistema
time.sleep(1)
pyautogui.moveTo(863, 260)
pyautogui.click()

#Cadastro
time.sleep(4)
pyautogui.moveTo(526, 111)
pyautogui.click()

#Tabelas de Frete
time.sleep(1)
pyautogui.moveTo(535, 151)
pyautogui.click()

#Nova Tabela
time.sleep(4)
pyautogui.moveTo(988, 222)
pyautogui.click()

#Selecionar transportador

#Escrever nome correto

#Origem e Coleta
time.sleep(1)
pyautogui.moveTo(510, 561)
pyautogui.click()
pyautogui.moveTo(511, 596)
pyautogui.click()

#Destino e Coleta
pyautogui.moveTo(505, 615)
pyautogui.click()
pyautogui.moveTo(570, 648)
pyautogui.click()

#Modal
pyautogui.moveTo(637, 651)
pyautogui.click()
pyautogui.moveTo(621, 719)
pyautogui.click()

if incoterm == 'CIF':
    #Natureza do transporte
    pyautogui.moveTo(496, 688)
    pyautogui.click()
    pyautogui.moveTo(496, 707)
    pyautogui.click()    
    pyautogui.moveTo(1016, 707)
    pyautogui.click()

    #Tipo de frete
    pyautogui.moveTo(499, 748)
    pyautogui.click()
    
else:
    #Natureza do transporte
    pyautogui.moveTo(1015, 687)
    pyautogui.click()
    pyautogui.moveTo(496, 707)
    pyautogui.click()    
    pyautogui.moveTo(1016, 707)
    pyautogui.click()

    #Tipo de frete
    pyautogui.moveTo(716, 748)
    pyautogui.click()
    
#Validade da tabela
pyautogui.moveTo(525, 796)
pyautogui.click()
pyautogui.write('14')
pyautogui.press('enter')
pyautogui.moveTo(655, 794)
pyautogui.click()
pyautogui.write('14/11')
pyautogui.press('enter')

#Frete Peso
pyautogui.moveTo(532, 393)
pyautogui.click()

#Frete Peso Adicionar
pyautogui.moveTo(1172, 513)
pyautogui.click()

#Frete Peso Adicionar
pyautogui.moveTo(455, 536)
pyautogui.click()
pyautogui.write('0')
pyautogui.press('enter')

#Sei Tx
pyautogui.moveTo(1038, 537)
pyautogui.click()

#Taxa
pyautogui.moveTo(1081, 540)
pyautogui.click()
pyautogui.write('0')
pyautogui.press('enter')

#Peso Acima de
pyautogui.moveTo(575, 560)
pyautogui.click()
pyautogui.write('0')
pyautogui.press('enter')

#Valor Acima de
pyautogui.moveTo(952, 558)
pyautogui.click()
pyautogui.write('0')
pyautogui.press('enter')

#Frete valor
pyautogui.moveTo(601, 391)
pyautogui.click()

#Adicionar
pyautogui.moveTo(1158, 438)
pyautogui.click()

#Acima de
pyautogui.moveTo(624, 487)
pyautogui.click()
pyautogui.write('0')
pyautogui.press('enter')

#Cobrar
pyautogui.moveTo(936, 487)
pyautogui.click()
pyautogui.write('0')
pyautogui.press('enter')

#De R$
pyautogui.moveTo(457, 463)
pyautogui.click()
pyautogui.write('0')
pyautogui.press('enter')

#Percentual
pyautogui.moveTo(838, 466)
pyautogui.click()
pyautogui.write('0')
pyautogui.press('enter')

#Valor
pyautogui.moveTo(1041, 463)
pyautogui.click()
pyautogui.write('0')
pyautogui.press('enter')

#Generalidades
pyautogui.moveTo(981, 388)
pyautogui.click()

if incoterm == 'CIF':
    #Natureza do transporte
    pyautogui.moveTo(529, 453)
    pyautogui.click()
else:
    #Natureza do transporte
    pyautogui.moveTo(529, 471)
    pyautogui.click()
    
#PIS/Cofins
pyautogui.moveTo(916, 454)
pyautogui.click()
pyautogui.write('0')
pyautogui.press('enter')

#GRIS até
pyautogui.moveTo(634, 493)
pyautogui.click()
pyautogui.write('0')
pyautogui.press('enter')

#GRIS percentual
pyautogui.moveTo(862, 496)
pyautogui.click()
pyautogui.write('0')
pyautogui.press('enter')

#GRIS percentual2
pyautogui.moveTo(872, 518)
pyautogui.click()
pyautogui.write('0')
pyautogui.press('enter')

#GRIS Minimo
pyautogui.moveTo(872, 518)
pyautogui.click()
pyautogui.write('0')
pyautogui.press('enter')

#Palet1
pyautogui.moveTo(595, 558)
pyautogui.click()
pyautogui.write('0')
pyautogui.press('enter')

#Palet2
pyautogui.moveTo(619, 577)
pyautogui.click()
pyautogui.write('0')
pyautogui.press('enter')

#Reentrega percentual
pyautogui.moveTo(584, 601)
pyautogui.click()
pyautogui.write('0')
pyautogui.press('enter')

#Reentrega minimo
pyautogui.moveTo(747, 538)
pyautogui.click()
pyautogui.write('0')
pyautogui.press('enter')

#Devolução percentual
pyautogui.moveTo(550, 629)
pyautogui.click()
pyautogui.write('0')
pyautogui.press('enter')

#Devolução minimo
pyautogui.moveTo(765, 537)
pyautogui.click()
pyautogui.write('0')
pyautogui.press('enter')

#Taxa permanência1
pyautogui.moveTo(553, 652)
pyautogui.click()
pyautogui.write('0')
pyautogui.press('enter')

#Taxa permanência2
pyautogui.moveTo(683, 652)
pyautogui.click()
pyautogui.write('0')
pyautogui.press('enter')

#Taxa permanência3
pyautogui.moveTo(836, 654)
pyautogui.click()
pyautogui.write('0')
pyautogui.press('enter')

#Pedágio por Faixa de peso
pyautogui.moveTo(607, 425)
pyautogui.click()

#Adicionar base do ICMS
pyautogui.moveTo(829, 450)
pyautogui.click()

#Adicionar
pyautogui.moveTo(841, 475)
pyautogui.click()

#Acima de:
pyautogui.moveTo(490, 523)
pyautogui.click()
pyautogui.write('0')
pyautogui.press('enter')

#Peso de KG (>):
pyautogui.moveTo(485, 497)
pyautogui.click()
pyautogui.write('0')
pyautogui.press('enter')

#Sel taxa
pyautogui.moveTo(887, 498)
pyautogui.click()
pyautogui.write('0')
pyautogui.press('enter')

#Taxa faixa de peso
pyautogui.moveTo(887, 498)
pyautogui.click(clicks=3)
pyautogui.write('0')
pyautogui.press('enter')

#Cidades e destinatários
pyautogui.moveTo(1048, 389)
pyautogui.click()

#Cidade
pyautogui.moveTo(1048, 389)
pyautogui.click()

#Destinatário
pyautogui.moveTo(1048, 389)
pyautogui.click()

#Eventos e restrições
pyautogui.moveTo(1211, 388)
pyautogui.click()

#Origem em
pyautogui.moveTo(738, 754)
pyautogui.click()
pyautogui.moveTo(782, 514)
pyautogui.click()
pyautogui.dragTo(785, 697, button='left')
# Out:
# ---------------------------------------------------------------------------
# FailSafeException                         Traceback (most recent call last)
# <ipython-input-1-40125a0ae363> in <module>
#     302 pyautogui.click(clicks=3)
#     303 pyautogui.write('0')
# --> 304 pyautogui.press('enter')
#     305
#     306 #Cidades e destinatários
#
# ~\anaconda3\lib\site-packages\pyautogui\__init__.py in wrapper(*args, **kwargs)
#     583     @functools.wraps(wrappedFunction)
#     584     def wrapper(*args, **kwargs):
# --> 585         failSafeCheck()
#     586         returnVal = wrappedFunction(*args, **kwargs)
#     587         _handlePause(kwargs.get("_pause", True))
#
# ~\anaconda3\lib\site-packages\pyautogui\__init__.py in failSafeCheck()
#    1708 def failSafeCheck():
#    1709     if FAILSAFE and tuple(position()) in FAILSAFE_POINTS:
# -> 1710         raise FailSafeException(
# ...

# %%
incoterm = 'CIF'
transportadora = 'OLM'
origem = 'OURO PRETO/MG'
destino = 'VINHEDO/SP'
toneladas = '25'
Acima_De = '28000'
Nome_tabela = (transportadora + ' - ' + origem + ' X '+ destino + ' - ' + toneladas + 'T')

# %%
import pyautogui
from datetime import datetime, timedelta
import time
import calendar

incoterm = 'CIF'

pyautogui.alert("Tire a mão do teclado e mouse!")
pyautogui.PAUSE = 0.5

#Loguin
pyautogui.press('winleft')
pyautogui.write('chrome')
pyautogui.press('enter')

time.sleep(1)
pyautogui.write('http://hindalco.simfrete.com.br/')
pyautogui.press('enter')
  
#Entrar sistema
time.sleep(1)
pyautogui.moveTo(650, 259)
pyautogui.click()

#Cadastro
time.sleep(4)
pyautogui.moveTo(527, 111)
pyautogui.click()

#Tabelas de Frete
time.sleep(1)
pyautogui.moveTo(557, 155)
pyautogui.click()

#Nova Tabela
time.sleep(4)
pyautogui.moveTo(767, 225)
pyautogui.click()

#Nome Tabela
time.sleep(4)
pyautogui.moveTo(278, 361)
pyautogui.click()
pyautogui.write(Nome_tabela)

#Frete Peso
time.sleep(1)
pyautogui.moveTo(311, 301)
pyautogui.click()

#adicionar
time.sleep(1)
pyautogui.moveTo(936, 419)
pyautogui.click()

#adicionar
time.sleep(1)
pyautogui.moveTo(334, 474)
pyautogui.click()
pyautogui.write(Acima_De)

# %%
pyautogui.position()
# Out:
# Point(x=311, y=301)
